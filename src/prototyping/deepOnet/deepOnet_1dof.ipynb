# %%
# %pip install uv
# %restart_python
# !uv sync --active #pip install -r "/Workspace/Users/aag@allseas.com/MSc_thesis/requirements.txt"
# %restart_python

# %%
import logging
import sys
from pathlib import Path

# Ensure project root is on sys.path so `src` is importable
_project_root = str(Path(__file__).resolve().parents[3]) if "__file__" in dir() else str(Path.cwd().parents[2])
if _project_root not in sys.path:
    sys.path.insert(0, _project_root)

from src.prototyping.deepOnet.deepOnet_1dof import main

# %%
main()
