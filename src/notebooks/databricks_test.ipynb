# %%
# List inside the Volume
files = dbutils.fs.ls("/Volumes/main_udev/ai_labs/aag/artifacts/.internal")

# Pick the newest wheel
latest_dbfs = max(files, key=lambda f: f.modificationTime).path  # e.g., "dbfs:/Volumes/.../thesis-1.0.4-..."
latest_local = latest_dbfs.replace("dbfs:", "")                  # -> "/Volumes/.../thesis-1.0.4-..."

print(f"Installing: {latest_local}")
# %pip install --force-reinstall "$latest_local"
                       # reinstall even if version is same
# %restart_python
# Out:
# ['C:\\Soft_dev\\python3.12.2\\python312.zip', 'C:\\Soft_dev\\python3.12.2\\DLLs', 'C:\\Soft_dev\\python3.12.2\\Lib', 'C:\\Soft_dev\\python3.12.2', 'c:\\Soft_dev\\MSc_thesis\\.venv', '', 'c:\\Soft_dev\\MSc_thesis\\.venv\\Lib\\site-packages', 'c:\\Soft_dev\\MSc_thesis\\.venv\\Lib\\site-packages\\win32', 'c:\\Soft_dev\\MSc_thesis\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Soft_dev\\MSc_thesis\\.venv\\Lib\\site-packages\\Pythonwin', 'c:\\Soft_dev\\MSc_thesis']

# %%
from thesis.test_func import test_func_2
test_func_2()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.thesis.test_func import test_func_2
#       2 test_func_2()
#
# ModuleNotFoundError: No module named 'src'
